# %%
import pandas as pd
import numpy as np


df = pd.DataFrame({
    " Employee ID ": [101, 102, 103, 104, 104, 106, None, 108, 109, 110],
    "Name": [
        " Alice ",
        "BOB",
        "charlie",
        "David",
        "David",
        np.nan,
        "Eva123",
        " Frank",
        "Grace ",
        "Henry@"
    ],
    "Age": [25, -5, 30, np.nan, 30, 200, 28, 22, np.nan, 35],
    "Gender": [
        "Male",
        "M",
        "Female",
        "F",
        "female",
        "male",
        "Unknown",
        "FEMALE",
        np.nan,
        "M "
    ],
    "Salary($)": [
        "$50000",
        "$60,000",
        "70000",
        "$80000",
        "$80000",
        np.nan,
        "$90,500",
        "abc",
        "$100000",
        "$110000"
    ],
    "Join Date": [
        "2022-01-10",
        "10/02/2022",
        "March 5, 2022",
        "2022/04/01",
        "2022/04/01",
        "Invalid",
        np.nan,
        "2022-08-15",
        "15-09-2022",
        "2022-10-01"
    ],
    "Department ": [
        "HR",
        "IT",
        "Finance",
        "IT",
        "IT",
        "Sales",
        "HR",
        "Finance",
        "Marketing",
        "Sales "
    ],
    "Active": [
        "Yes",
        "Y",
        "1",
        "No",
        "0",
        "True",
        "False",
        "yes",
        "N",
        np.nan
    ]
})
df
# Out:
#     Employee ID      Name    Age   Gender Salary($)      Join Date  \
# 0          101.0   Alice    25.0     Male    $50000     2022-01-10
# 1          102.0      BOB   -5.0        M   $60,000     10/02/2022
# 2          103.0  charlie   30.0   Female     70000  March 5, 2022
# 3          104.0    David    NaN        F    $80000     2022/04/01
# 4          104.0    David   30.0   female    $80000     2022/04/01
# 5          106.0      NaN  200.0     male       NaN        Invalid
# 6            NaN   Eva123   28.0  Unknown   $90,500            NaN
# 7          108.0    Frank   22.0   FEMALE       abc     2022-08-15
# 8          109.0   Grace     NaN      NaN   $100000     15-09-2022
# 9          110.0   Henry@   35.0       M    $110000     2022-10-01
#
#   Department  Active
# 0          HR    Yes
# 1          IT      Y
# 2     Finance      1
# 3          IT     No
# 4          IT      0
# 5       Sales   True
# 6          HR  False
# 7     Finance    yes
# 8   Marketing      N
# ...
